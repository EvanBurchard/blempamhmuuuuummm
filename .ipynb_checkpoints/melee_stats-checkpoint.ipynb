# %% [markdown]
# # Add games to analytics directory as json

# %% [markdown]
# ## Setup

# %%
import os
from os import listdir
from os.path import isfile, join

# %% [markdown]
# ## Add Single Game

# %%
game_path = "test_game.slp"
os.system('node stats.js' + ' ' + game_path)
# Out:
# 0

# %% [markdown]
# ## Add multiple games

# %%
games_path = "../../Slippi"
game_files = [games_path + '/' + f for f in listdir(games_path) if isfile(join(games_path, f))]

# %%
# this took about an hour for 6000 games
for file_name in game_files:
    os.system('node stats.js' + ' ' + file_name)

# %% [markdown]
# # Import game analytics into Pandas

# %% [markdown]
# ## Setup

# %%
import numpy as np
import pandas as pd
import json

# %% [markdown]
# ## Single game

# %%
def load_single_game(game_file, output):
    
    with open(game_file) as f:
        d = json.load(f)
    
    with open("characters.json") as f:
        characters = json.load(f)
    
    with open("moves.json") as f:
        moves = json.load(f)
    
    with open("stages.json") as f:
        stages = json.load(f)
    
    
    df = pd.json_normalize(d, max_level=1)
    if d['metadata']:
        x = pd.DataFrame()
        x['game_length'] = df['stats.playableFrameCount'] / 60
        x['stage'] = df['settings.stageId'].astype(str).map(stages)
        
        player_one = df["settings.players"][0][0]
        player_two = df["settings.players"][0][1]
        x['player_one_display_name'] = player_one["displayName"]
        x['player_two_display_name'] = player_two["displayName"]
        x['player_one_connect_code'] = player_one["connectCode"]
        x['player_two_connect_code'] = player_two["connectCode"]
        x['player_one_user_id'] = player_one["userId"]
        x['player_two_user_id'] = player_two["userId"]
    
        x['player_one_character'] = characters[str(player_one["characterId"])]['name']
        x['player_two_character'] = characters[str(player_two["characterId"])]['name']
    
        # These won't work till default colors are added (prepended) to characters.json
        # x['player_one_character_color'] = characters[str(player_one["characterId"])]['colors'][player_one["characterColor"]]
        # x['player_two_character_color'] = characters[str(player_two["characterId"])]['colors'][player_two["characterColor"]]
    
        stock_lost_counter = [0, 0]
        stocks_lost = [stock['playerIndex'] for stock in df['stats.stocks'][0] if stock['endFrame']]
        for stock in stocks_lost:
            if stock == 0:
                stock_lost_counter[0] += 1
            else:
                stock_lost_counter[1] += 1
    
        x['player_one_lost_stocks'] = stock_lost_counter[0]
        x['player_two_lost_stocks'] = stock_lost_counter[1]
        if stock_lost_counter[0] == stock_lost_counter[1]:
            x['winner'] = None
            x['winner_id'] = None
        elif stock_lost_counter[0] < stock_lost_counter[1]:
            x['winner'] = 0
            x['winner_id'] = player_one["userId"]
            x['winning_character'] = x["player_one_character"]
            x['loser_id'] = player_two["userId"]
            x['losing_character'] = x["player_two_character"]

        else:
            x['winner'] = 1
            x['winner_id'] = player_two["userId"]
            x['winning_character'] = x["player_two_character"]
            x['loser_id'] = player_one["userId"]
            x['losing_character'] = x["player_one_character"]

        x['played_at'] = df['metadata.startAt']
        x['overall'] = df['stats.overall']
        x['action_counts'] = df['stats.actionCounts']
        x['game_complete'] = df['stats.gameComplete']
        
        output = pd.concat([output, x], ignore_index=True)
        # print(output.shape)
        return output
    else:
        print("something went wrong with: ", game_file)
        # print(output.shape)
        return output


output = load_single_game('game_analytics/Game_20230809T191315.json', pd.DataFrame())
output
# Out:
#    game_length          stage player_one_display_name player_two_display_name  \
# 0   217.083333  Yoshi's Story                    with                 VHSTAPE
#
#   player_one_connect_code player_two_connect_code  \
# 0                  WITH#0                 VHS#396
#
#              player_one_user_id            player_two_user_id  \
# 0  aPmT3TcxYLaUAlxSDKDsfKFmXC72  WweIVWmBLXSa9Tv6VG8dmYPDJ8Z2
#
#   player_one_character player_two_character  ...  player_two_lost_stocks  \
# 0                Yoshi                Peach  ...                       2
#
#    winner                     winner_id winning_character  \
# 0       1  WweIVWmBLXSa9Tv6VG8dmYPDJ8Z2             Peach
#
#                        loser_id losing_character             played_at  \
# 0  aPmT3TcxYLaUAlxSDKDsfKFmXC72            Yoshi  2023-08-09T23:13:15Z
#
#                                              overall  \
# 0  [{'playerIndex': 0, 'inputCounts': {'buttons':...
#
#                                        action_counts game_complete
# 0  [{'playerIndex': 0, 'wavedashCount': 0, 'wavel...          True
#
# [1 rows x 21 columns]

# %% [markdown]
# ## Multiple games

# %%
analytics_path = "game_analytics"
analytics_files = [analytics_path + '/' + f for f in listdir(analytics_path) if isfile(join(analytics_path, f))]

output = pd.DataFrame()
for i, f in enumerate(analytics_files):
    # print(i)
    # if i>1000:
    #     break
    try:
        output = load_single_game(f, output)
    except:
        print("An exception occurred for: ") 
        print(f)
# Out:
# something went wrong with:  game_analytics/Game_20231002T112717.json
# something went wrong with:  game_analytics/Game_20230821T074359.json
# something went wrong with:  game_analytics/.DS_Store
# something went wrong with:  game_analytics/Game_20231003T144755.json
# something went wrong with:  game_analytics/Game_20230810T141105.json
# something went wrong with:  game_analytics/Game_20231001T235749.json
# something went wrong with:  game_analytics/Game_20231018T195855.json
# something went wrong with:  game_analytics/Game_20230827T101530.json
# something went wrong with:  game_analytics/Game_20230807T091818.json
# something went wrong with:  game_analytics/Game_20230806T200651.json
# something went wrong with:  game_analytics/Game_20230814T213419.json
# something went wrong with:  game_analytics/Game_20230722T085734.json
# something went wrong with:  game_analytics/Game_20231021T081930.json
# something went wrong with:  game_analytics/Game_20230906T150537.json
# something went wrong with:  game_analytics/Game_20230721T154233.json
# something went wrong with:  game_analytics/Game_20230919T003340.json
# something went wrong with:  game_analytics/Game_20230804T181006.json
# something went wrong with:  game_analytics/Game_20230917T001954.json
# something went wrong with:  game_analytics/Game_20230719T212031.json
# something went wrong with:  game_analytics/Game_20230831T233723.json
# something went wrong with:  game_analytics/Game_20230922T142630.json
# something went wrong with:  game_analytics/Game_20230806T155811.json
# something went wrong with:  game_analytics/Game_20230812T185130.json
# something went wrong with:  game_analytics/Game_20230720T235701.json
# something went wrong with:  game_analytics/Game_20230721T144131.json
# something went wrong with:  game_analytics/Game_20230902T222535.json

# %%
output
# Out:
#     game_length               stage player_one_display_name  \
# 0     32.900000     Pokémon Stadium                    with
# 0    217.083333       Yoshi's Story                    with
# 0    102.533333     Pokémon Stadium              Matcha Man
# 0     46.583333       Yoshi's Story                    with
# 0     65.166667  Fountain of Dreams                    ITSU
# ..          ...                 ...                     ...
# 0    228.950000       Yoshi's Story                    with
# 0     36.716667     Pokémon Stadium                    with
# 0    157.400000  Fountain of Dreams                     KEV
# 0    239.016667      Dream Land N64                    with
# 0    233.566667   Final Destination                 The_OG_
#
#    player_two_display_name player_one_connect_code player_two_connect_code  \
# 0                     meow                  WITH#0                MEOW#339
# 0                  VHSTAPE                  WITH#0                 VHS#396
# 0                     with                MATC#818                  WITH#0
# 0                   Shlomp                  WITH#0                CLOR#884
# 0                     with                ITSU#117                  WITH#0
# ..                     ...                     ...                     ...
# 0                   Jotyde                  WITH#0                JOTY#425
# 0              bradday0429                  WITH#0                BRAD#102
# 0                     with                  SSC#23                  WITH#0
# 0                    ttocs                  WITH#0                TTOX#608
# 0                     with                YEET#210                  WITH#0
#
#               player_one_user_id            player_two_user_id  \
# 0   aPmT3TcxYLaUAlxSDKDsfKFmXC72  mwKYA5rvxaYBjYNpdEe8b39L7un2
# 0   aPmT3TcxYLaUAlxSDKDsfKFmXC72  WweIVWmBLXSa9Tv6VG8dmYPDJ8Z2
# 0   Es93fbpkTRMBc1EPfiSHlfs2cMv1  aPmT3TcxYLaUAlxSDKDsfKFmXC72
# 0   aPmT3TcxYLaUAlxSDKDsfKFmXC72  30cOiOMWLraUtgA8JltYkeO3cI82
# 0   NwRhZmeQYhQL13p8BCGqSLYGwAG2  aPmT3TcxYLaUAlxSDKDsfKFmXC72
# ..                           ...                           ...
# 0   aPmT3TcxYLaUAlxSDKDsfKFmXC72  OZhNnyBDstWxqxN8Sic9YPsns9B3
# 0   aPmT3TcxYLaUAlxSDKDsfKFmXC72  sVNWjJMzpGQ4w4iZFxcp0nvnL3n2
# 0   7eIllMJ4nCSpZnZwoYJCJMfKRnq2  aPmT3TcxYLaUAlxSDKDsfKFmXC72
# 0   aPmT3TcxYLaUAlxSDKDsfKFmXC72  W7JRcoIdRyMSCXHquOMoB8EOT7L2
# 0   albXMPtL1YWbyrRisa2MF9NTJi63  aPmT3TcxYLaUAlxSDKDsfKFmXC72
#
#    player_one_character player_two_character  player_one_lost_stocks  \
# 0                 Yoshi                Marth                       0
# 0                 Yoshi                Peach                       4
# 0                 Peach                Yoshi                       1
# 0                 Yoshi                Marth                       0
# 0             Dr. Mario                Yoshi                       1
# ..                  ...                  ...                     ...
# 0                 Yoshi                  Fox                       2
# 0                 Yoshi                Luigi                       0
# 0        Captain Falcon                Yoshi                       4
# 0                 Yoshi       Captain Falcon                       4
# 0                 Falco                Yoshi                       4
#
#     player_two_lost_stocks winner                     winner_id  \
# 0                        0   None                          None
# 0                        2      1  WweIVWmBLXSa9Tv6VG8dmYPDJ8Z2
# 0                        0      1  aPmT3TcxYLaUAlxSDKDsfKFmXC72
# 0                        0   None                          None
# 0                        0      1  aPmT3TcxYLaUAlxSDKDsfKFmXC72
# ..                     ...    ...                           ...
# 0                        4      0  aPmT3TcxYLaUAlxSDKDsfKFmXC72
# 0                        1      0  aPmT3TcxYLaUAlxSDKDsfKFmXC72
# 0                        2      1  aPmT3TcxYLaUAlxSDKDsfKFmXC72
# 0                        2      1  W7JRcoIdRyMSCXHquOMoB8EOT7L2
# 0                        3      1  aPmT3TcxYLaUAlxSDKDsfKFmXC72
#
#                played_at                                            overall  \
# 0   2023-08-17T23:48:00Z  [{'playerIndex': 0, 'inputCounts': {'buttons':...
# 0   2023-08-09T23:13:15Z  [{'playerIndex': 0, 'inputCounts': {'buttons':...
# 0   2023-09-11T20:02:15Z  [{'playerIndex': 0, 'inputCounts': {'buttons':...
# 0   2023-08-22T00:41:20Z  [{'playerIndex': 0, 'inputCounts': {'buttons':...
# 0   2023-07-24T04:17:04Z  [{'playerIndex': 0, 'inputCounts': {'buttons':...
# ..                   ...                                                ...
# 0   2023-09-14T03:33:20Z  [{'playerIndex': 0, 'inputCounts': {'buttons':...
# 0   2023-10-22T05:43:25Z  [{'playerIndex': 0, 'inputCounts': {'buttons':...
# 0   2023-10-02T17:20:29Z  [{'playerIndex': 0, 'inputCounts': {'buttons':...
# 0   2023-09-05T02:44:45Z  [{'playerIndex': 0, 'inputCounts': {'buttons':...
# 0   2023-08-14T05:07:00Z  [{'playerIndex': 0, 'inputCounts': {'buttons':...
#
#                                         action_counts  game_complete
# 0   [{'playerIndex': 0, 'wavedashCount': 0, 'wavel...           True
# 0   [{'playerIndex': 0, 'wavedashCount': 0, 'wavel...           True
# 0   [{'playerIndex': 0, 'wavedashCount': 4, 'wavel...           True
# 0   [{'playerIndex': 0, 'wavedashCount': 0, 'wavel...           True
# 0   [{'playerIndex': 0, 'wavedashCount': 1, 'wavel...           True
# ..                                                ...            ...
# 0   [{'playerIndex': 0, 'wavedashCount': 0, 'wavel...           True
# 0   [{'playerIndex': 0, 'wavedashCount': 0, 'wavel...           True
# 0   [{'playerIndex': 0, 'wavedashCount': 0, 'wavel...           True
# 0   [{'playerIndex': 0, 'wavedashCount': 0, 'wavel...           True
# 0   [{'playerIndex': 0, 'wavedashCount': 30, 'wave...           True
#
# [6010 rows x 18 columns]

# %% [markdown]
# # Queries

# %% [markdown]
# ## Win Rates

# %%
def wins(output, my_id):
    return output.loc[(output['winner_id'] == my_id)]

def losses(output, my_id):
    return output.loc[(output['loser_id'] == my_id)]
    
def win_rates(output, my_id):
    w = wins(output, my_id)
    l = losses(output, my_id)
    undetermined = output.loc[(output['winner_id'].isnull())]
    return w.shape[0], l.shape[0], w.shape[0] / (w.shape[0] + l.shape[0])


def win_rates_by_character(output, my_id, my_character, their_character):
    
    w = wins(output, my_id)
    l = losses(output, my_id)

    # scope wins by character
    # scope losses by character
    print(w['losing_character'] == my_character)
    
    w = w.loc[(w['winning_character'] == my_character & w['losing_character'] == their_character)]
    l = l.loc[(l['winning_character'] == their_character & l['losing_character'] == my_character)]

    return w.shape[0], l.shape[0], w.shape[0] / (w.shape[0] + l.shape[0])

my_id ="aPmT3TcxYLaUAlxSDKDsfKFmXC72"
overall = win_rates(output, my_id)
print("wins: ", overall[0], "\nlosses: ", overall[1], "\nwin rate: ", overall[2])

win_rates_by_character(output, my_id, "Yoshi", "Fox")


char_names = ["Captain Falcon", "Donkey Kong", "Fox", "Mr. Game & Watch", "Kirby", "Bowser",
 "Link", "Luigi", "Mario", "Marth", "Mewtwo", "Ness", "Peach", "Pikachu", "Ice Climbers", 
 "Jigglypuff", "Samus", "Yoshi", "Zelda", "Sheik", "Falco", "Young Link", "Dr. Mario", "Roy", "Pichu", "Ganondorf"]
# Out:
# wins:  2380
# losses:  2715
# win rate:  0.46712463199214915
# 2       False
# 4       False
# 6       False
# 8       False
# 11      False
#         ...
# 6000    False
# 6005    False
# 6006    False
# 6007    False
# 6009    False
# Name: losing_character, Length: 2380, dtype: bool
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/ops/array_ops.py:364, in na_logical_op(x, y, op)
#     355 try:
#     356     # For exposition, write:
#     357     #  yarr = isinstance(y, np.ndarray)
#    (...)
#     362     # Then Cases where this goes through without raising include:
#     363     #  (xint or xbool) and (yint or bool)
# --> 364     result = op(x, y)
#     365 except TypeError:
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/roperator.py:54, in rand_(left, right)
#      53 def rand_(left, right):
# ---> 54     return operator.and_(right, left)
#
# TypeError: unsupported operand type(s) for &: 'str' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/ops/array_ops.py:378, in na_logical_op(x, y, op)
#     377 try:
# --> 378     result = libops.scalar_binop(x, y, op)
#     379 except (
#     380     TypeError,
#     381     ValueError,
#    (...)
#     384     NotImplementedError,
#     385 ) as err:
#
# File ops.pyx:210, in pandas._libs.ops.scalar_binop()
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/roperator.py:54, in rand_(left, right)
#      53 def rand_(left, right):
# ---> 54     return operator.and_(right, left)
#
# TypeError: unsupported operand type(s) for &: 'bool' and 'str'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[306], line 32
#      29 overall = win_rates(output, my_id)
#      30 print("wins: ", overall[0], "\nlosses: ", overall[1], "\nwin rate: ", overall[2])
# ---> 32 win_rates_by_character(output, my_id, "Yoshi", "Fox")
#      35 char_names = ["Captain Falcon", "Donkey Kong", "Fox", "Mr. Game & Watch", "Kirby", "Bowser",
#      36  "Link", "Luigi", "Mario", "Marth", "Mewtwo", "Ness", "Peach", "Pikachu", "Ice Climbers",
#      37  "Jigglypuff", "Samus", "Yoshi", "Zelda", "Sheik", "Falco", "Young Link", "Dr. Mario", "Roy", "Pichu", "Ganondorf"]
#
# Cell In[306], line 23, in win_rates_by_character(output, my_id, my_character, their_character)
#      19 # scope wins by character
#      20 # scope losses by character
#      21 print(w['losing_character'] == my_character)
# ---> 23 w = w.loc[(w['winning_character'] == my_character & w['losing_character'] == their_character)]
#      24 l = l.loc[(l['winning_character'] == their_character & l['losing_character'] == my_character)]
#      26 return w.shape[0], l.shape[0], w.shape[0] / (w.shape[0] + l.shape[0])
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/ops/common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/arraylike.py:74, in OpsMixin.__rand__(self, other)
#      72 @unpack_zerodim_and_defer("__rand__")
#      73 def __rand__(self, other):
# ---> 74     return self._logical_method(other, roperator.rand_)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/series.py:5810, in Series._logical_method(self, other, op)
#    5807 lvalues = self._values
#    5808 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
# -> 5810 res_values = ops.logical_op(lvalues, rvalues, op)
#    5811 return self._construct_result(res_values, name=res_name)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/ops/array_ops.py:456, in logical_op(left, right, op)
#     452 else:
#     453     # i.e. scalar
#     454     is_other_int_dtype = lib.is_integer(rvalues)
# --> 456 res_values = na_logical_op(lvalues, rvalues, op)
#     458 # For int vs int `^`, `|`, `&` are bitwise operators and return
#     459 #   integer dtypes.  Otherwise these are boolean ops
#     460 if not (left.dtype.kind in "iu" and is_other_int_dtype):
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/ops/array_ops.py:387, in na_logical_op(x, y, op)
#     379         except (
#     380             TypeError,
#     381             ValueError,
#    (...)
#     384             NotImplementedError,
#     385         ) as err:
#     386             typ = type(y).__name__
# --> 387             raise TypeError(
#     388                 f"Cannot perform '{op.__name__}' with a dtyped [{x.dtype}] array "
#     389                 f"and scalar of type [{typ}]"
#     390             ) from err
#     392 return result.reshape(x.shape)
#
# TypeError: Cannot perform 'rand_' with a dtyped [object] array and scalar of type [bool]

# %%
output.loc[(output['winner_id'] == "aPmT3TcxYLaUAlxSDKDsfKFmXC72")].shape[0]
# Out:
# 2380
