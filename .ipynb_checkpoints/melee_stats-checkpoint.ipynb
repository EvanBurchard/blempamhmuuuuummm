# %% [markdown]
# # Add games to analytics directory as json

# %% [markdown]
# ## Setup

# %%
import os
from os import listdir
from os.path import isfile, join

# %% [markdown]
# ## Add Single Game

# %%
game_path = "test_game.slp"
os.system('node stats.js' + ' ' + game_path)
# Out:
# 0

# %% [markdown]
# ## Add multiple games

# %%
games_path = "../../Slippi"
game_files = [games_path + '/' + f for f in listdir(games_path) if isfile(join(games_path, f))]

# %%
# this took about an hour for 6000 games
for file_name in game_files:
    os.system('node stats.js' + ' ' + file_name)

# %% [markdown]
# # Import game analytics into Pandas

# %% [markdown]
# ## Setup

# %%
import numpy as np
import pandas as pd
import json

# %% [markdown]
# ## Single game

# %%
def load_single_game(game_file, output):
    
    with open(game_file) as f:
        d = json.load(f)
    
    with open("characters.json") as f:
        characters = json.load(f)
    
    with open("moves.json") as f:
        moves = json.load(f)
    
    with open("stages.json") as f:
        stages = json.load(f)
    
    
    df = pd.json_normalize(d, max_level=1)
    if d['metadata']:
        x = pd.DataFrame()
        x['game_length'] = df['stats.playableFrameCount'] / 60
        x['stage'] = df['settings.stageId'].astype(str).map(stages)
        
        player_one = df["settings.players"][0][0]
        player_two = df["settings.players"][0][1]
        x['player_one_display_name'] = player_one["displayName"]
        x['player_two_display_name'] = player_two["displayName"]
        x['player_one_connect_code'] = player_one["connectCode"]
        x['player_two_connect_code'] = player_two["connectCode"]
        x['player_one_user_id'] = player_one["userId"]
        x['player_two_user_id'] = player_two["userId"]
    
        x['player_one_character'] = characters[str(player_one["characterId"])]['name']
        x['player_two_character'] = characters[str(player_two["characterId"])]['name']
    
        # These won't work till default colors are added (prepended) to characters.json
        # x['player_one_character_color'] = characters[str(player_one["characterId"])]['colors'][player_one["characterColor"]]
        # x['player_two_character_color'] = characters[str(player_two["characterId"])]['colors'][player_two["characterColor"]]
    
        stock_lost_counter = [0, 0]
        stocks_lost = [stock['playerIndex'] for stock in df['stats.stocks'][0] if stock['endFrame']]
        for stock in stocks_lost:
            if stock == 0:
                stock_lost_counter[0] += 1
            else:
                stock_lost_counter[1] += 1
    
        x['player_one_lost_stocks'] = stock_lost_counter[0]
        x['player_two_lost_stocks'] = stock_lost_counter[1]
        if stock_lost_counter[0] == stock_lost_counter[1]:
            x['winner'] = None
        elif stock_lost_counter[0] < stock_lost_counter[1]:
            x['winner'] = 0
        else:
            x['winner'] = 1
        x['played_at'] = df['metadata.startAt']
        x['overall'] = df['stats.overall']
        x['action_counts'] = df['stats.actionCounts']
        x['game_complete'] = df['stats.gameComplete']
        
        output = pd.concat([output, x])
        return output


output = load_single_game('game_analytics/Game_20230817T194800.json', pd.DataFrame())
output
# Out:
#                                game_name settings.slpVersion  \
# 0  ../../Slippi/Game_20230817T194800.slp              3.15.0
#
#    settings.timerType  settings.inGameMode  settings.friendlyFireEnabled  \
# 0                   2                   32                          True
#
#    settings.isTeams  settings.itemSpawnBehavior  settings.stageId  \
# 0             False                         255                 3
#
#    settings.startingTimerSeconds  settings.enabledItems  ...  \
# 0                            480          1099511627775  ...
#
#                                     metadata.players  metadata.playedOn  \
# 0  {'0': {'names': {'netplay': 'with', 'code': 'W...            dolphin
#
#    stats.lastFrame  stats.playableFrameCount  \
# 0             1935                      1974
#
#                                         stats.stocks  \
# 0  [{'playerIndex': 0, 'startFrame': -123, 'endFr...
#
#                                    stats.conversions  \
# 0  [{'playerIndex': 0, 'lastHitBy': 1, 'startFram...
#
#                                         stats.combos  \
# 0  [{'playerIndex': 0, 'startFrame': 86, 'endFram...
#
#                                   stats.actionCounts  \
# 0  [{'playerIndex': 0, 'wavedashCount': 0, 'wavel...
#
#                                        stats.overall stats.gameComplete
# 0  [{'playerIndex': 0, 'inputCounts': {'buttons':...               True
#
# [1 rows x 31 columns]
#    game_length            stage player_one_display_name  \
# 0         32.9  Pokémon Stadium                    with
#
#   player_two_display_name player_one_connect_code player_two_connect_code  \
# 0                    meow                  WITH#0                MEOW#339
#
#              player_one_user_id            player_two_user_id  \
# 0  aPmT3TcxYLaUAlxSDKDsfKFmXC72  mwKYA5rvxaYBjYNpdEe8b39L7un2
#
#   player_one_character player_two_character  player_one_lost_stocks  \
# 0                Yoshi                Marth                       0
#
#    player_two_lost_stocks winner             played_at  \
# 0                       0   None  2023-08-17T23:48:00Z
#
#                                              overall  \
# 0  [{'playerIndex': 0, 'inputCounts': {'buttons':...
#
#                                        action_counts  game_complete
# 0  [{'playerIndex': 0, 'wavedashCount': 0, 'wavel...           True

# %% [markdown]
# ## Multiple games

# %%
analytics_path = "game_analytics"
analytics_files = [analytics_path + '/' + f for f in listdir(analytics_path) if isfile(join(analytics_path, f))]

output = pd.DataFrame()
for i, f in enumerate(analytics_files):
    if i>1000:
        break
    try:
        output = load_single_game(f, output)
    except:
        print("An exception occurred for: ") 
        print(f)
# Out:
#                                game_name settings.slpVersion  \
# 0  ../../Slippi/Game_20230817T194800.slp              3.15.0
#
#    settings.timerType  settings.inGameMode  settings.friendlyFireEnabled  \
# 0                   2                   32                          True
#
#    settings.isTeams  settings.itemSpawnBehavior  settings.stageId  \
# 0             False                         255                 3
#
#    settings.startingTimerSeconds  settings.enabledItems  ...  \
# 0                            480          1099511627775  ...
#
#                                     metadata.players  metadata.playedOn  \
# 0  {'0': {'names': {'netplay': 'with', 'code': 'W...            dolphin
#
#    stats.lastFrame  stats.playableFrameCount  \
# 0             1935                      1974
#
#                                         stats.stocks  \
# 0  [{'playerIndex': 0, 'startFrame': -123, 'endFr...
#
#                                    stats.conversions  \
# 0  [{'playerIndex': 0, 'lastHitBy': 1, 'startFram...
#
#                                         stats.combos  \
# 0  [{'playerIndex': 0, 'startFrame': 86, 'endFram...
#
#                                   stats.actionCounts  \
# 0  [{'playerIndex': 0, 'wavedashCount': 0, 'wavel...
#
#                                        stats.overall stats.gameComplete
# 0  [{'playerIndex': 0, 'inputCounts': {'buttons':...               True
#
# [1 rows x 31 columns]
#                                game_name settings.slpVersion  \
# 0  ../../Slippi/Game_20230809T191315.slp              3.15.0
#
#    settings.timerType  settings.inGameMode  settings.friendlyFireEnabled  \
# 0                   2                   32                          True
#
#    settings.isTeams  settings.itemSpawnBehavior  settings.stageId  \
# 0             False                         255                 8
#
#    settings.startingTimerSeconds  settings.enabledItems  ...  \
# 0                            480          1099511627775  ...
#
#                                     metadata.players  metadata.playedOn  \
# 0  {'0': {'names': {'netplay': 'with', 'code': 'W...            dolphin
#
#    stats.lastFrame  stats.playableFrameCount  \
# 0            12986                     13025
#
#                                         stats.stocks  \
# 0  [{'playerIndex': 0, 'startFrame': -123, 'endFr...
#
#                                    stats.conversions  \
# 0  [{'playerIndex': 0, 'lastHitBy': 1, 'startFram...
#
#                                         stats.combos  \
# 0  [{'playerIndex': 0, 'startFrame': 36, 'endFram...
#
#                                   stats.actionCounts  \
# 0  [{'playerIndex': 0, 'wavedashCount': 0, 'wavel...
#
#                                        stats.overall stats.gameComplete
# 0  [{'playerIndex': 0, 'inputCounts': {'buttons':...               True
#
# [1 rows x 31 columns]
#                                game_name settings.slpVersion  \
# 0  ../../Slippi/Game_20230911T160215.slp              3.15.0
#
#    settings.timerType  settings.inGameMode  settings.friendlyFireEnabled  \
# 0                   2                   32                          True
#
#    settings.isTeams  settings.itemSpawnBehavior  settings.stageId  \
# 0             False                         255                 3
#
#    settings.startingTimerSeconds  settings.enabledItems  ...  \
# 0                            480          1099511627775  ...
#
#                                     metadata.players  metadata.playedOn  \
# 0  {'0': {'names': {'netplay': 'Matcha Man', 'cod...            dolphin
#
#    stats.lastFrame  stats.playableFrameCount  \
# 0             6113                      6152
#
#                                         stats.stocks  \
# 0  [{'playerIndex': 0, 'startFrame': -123, 'endFr...
#
#                                    stats.conversions  \
# 0  [{'playerIndex': 0, 'lastHitBy': 1, 'startFram...
#
#                                         stats.combos  \
# 0  [{'playerIndex': 0, 'startFrame': 27, 'endFram...
#
#                                   stats.actionCounts  \
# 0  [{'playerIndex': 0, 'wavedashCount': 4, 'wavel...
#
#                                        stats.overall stats.gameComplete
# 0  [{'playerIndex': 0, 'inputCounts': {'buttons':...               True
#
# [1 rows x 31 columns]
#                                game_name settings.slpVersion  \
# 0  ../../Slippi/Game_20230821T204120.slp              3.15.0
#
#    settings.timerType  settings.inGameMode  settings.friendlyFireEnabled  \
# 0                   2                   32                          True
#
#    settings.isTeams  settings.itemSpawnBehavior  settings.stageId  \
# 0             False                         255                 8
#
#    settings.startingTimerSeconds  settings.enabledItems  ...  \
# 0                            480          1099511627775  ...
#
#                                     metadata.players  metadata.playedOn  \
# 0  {'0': {'names': {'netplay': 'with', 'code': 'W...            dolphin
#
#    stats.lastFrame  stats.playableFrameCount  \
# 0             2756                      2795
#
#                                         stats.stocks  \
# 0  [{'playerIndex': 0, 'startFrame': -123, 'endFr...
#
#                                    stats.conversions  \
# 0  [{'playerIndex': 0, 'lastHitBy': 1, 'startFram...
#
#                                         stats.combos  \
# 0  [{'playerIndex': 0, 'startFrame': 295, 'endFra...
#
#                                   stats.actionCounts  \
# 0  [{'playerIndex': 0, 'wavedashCount': 0, 'wavel...
#
#                                        stats.overall stats.gameComplete
# 0  [{'playerIndex': 0, 'inputCounts': {'buttons':...               True
#
# [1 rows x 31 columns]
#                                game_name settings.slpVersion  \
# 0  ../../Slippi/Game_20230724T001704.slp              3.15.0
#
#    settings.timerType  settings.inGameMode  settings.friendlyFireEnabled  \
# 0                   2                   32                          True
#
#    settings.isTeams  settings.itemSpawnBehavior  settings.stageId  \
# 0             False                         255                 2
#
#    settings.startingTimerSeconds  settings.enabledItems  ...  \
# 0                            480          1099511627775  ...
#
#                                     metadata.players  metadata.playedOn  \
# 0  {'0': {'names': {'netplay': 'ITSU', 'code': 'I...            dolphin
#
#    stats.lastFrame  stats.playableFrameCount  \
# 0             3871                      3910
#
#                                         stats.stocks  \
# 0  [{'playerIndex': 0, 'startFrame': -123, 'endFr...
#
#                                    stats.conversions  \
# 0  [{'playerIndex': 1, 'lastHitBy': 0, 'startFram...
#
#                                         stats.combos  \
# 0  [{'playerIndex': 1, 'startFrame': 64, 'endFram...
#
#                                   stats.actionCounts  \
# 0  [{'playerIndex': 0, 'wavedashCount': 1, 'wavel...
#
#                                        stats.overall stats.gameComplete
# 0  [{'playerIndex': 0, 'inputCounts': {'buttons':...               True
#
# [1 rows x 31 columns]
#                                game_name settings.slpVersion  \
# 0  ../../Slippi/Game_20230903T222440.slp              3.15.0
#
#    settings.timerType  settings.inGameMode  settings.friendlyFireEnabled  \
# 0                   2                   32                          True
#
#    settings.isTeams  settings.itemSpawnBehavior  settings.stageId  \
# 0             False                         255                32
#
#    settings.startingTimerSeconds  settings.enabledItems  ...  \
# 0                            480          1099511627775  ...
#
#                                     metadata.players  metadata.playedOn  \
# 0  {'0': {'names': {'netplay': 'hd', 'code': 'HDH...            dolphin
#
#    stats.lastFrame  stats.playableFrameCount  \
# 0            10773                     10812
#
#                                         stats.stocks  \
# 0  [{'playerIndex': 0, 'startFrame': -123, 'endFr...
#
#                                    stats.conversions  \
# 0  [{'playerIndex': 1, 'lastHitBy': 0, 'startFram...
#
#                                         stats.combos  \
# 0  [{'playerIndex': 1, 'startFrame': 36, 'endFram...
#
#                                   stats.actionCounts  \
# 0  [{'playerIndex': 0, 'wavedashCount': 19, 'wave...
#
#                                        stats.overall stats.gameComplete
# 0  [{'playerIndex': 0, 'inputCounts': {'buttons':...               True
#
# [1 rows x 31 columns]
#                                game_name settings.slpVersion  \
# 0  ../../Slippi/Game_20230722T163505.slp              3.15.0
#
#    settings.timerType  settings.inGameMode  settings.friendlyFireEnabled  \
# 0                   2                   32                          True
#
#    settings.isTeams  settings.itemSpawnBehavior  settings.stageId  \
# 0             False                         255                 2
#
#    settings.startingTimerSeconds  settings.enabledItems  ...  \
# 0                            480          1099511627775  ...
#
#                                     metadata.players  metadata.playedOn  \
# 0  {'0': {'names': {'netplay': 'with', 'code': 'W...            dolphin
#
#    stats.lastFrame  stats.playableFrameCount  \
# 0             1042                      1081
#
#                                         stats.stocks  \
# 0  [{'playerIndex': 0, 'startFrame': -123, 'endFr...
#
#                                    stats.conversions  \
# 0  [{'playerIndex': 1, 'lastHitBy': 0, 'startFram...
#
#                                         stats.combos  \
# 0  [{'playerIndex': 1, 'startFrame': 151, 'endFra...
#
#                                   stats.actionCounts  \
# 0  [{'playerIndex': 0, 'wavedashCount': 0, 'wavel...
#
#                                        stats.overall stats.gameComplete
# 0  [{'playerIndex': 0, 'inputCounts': {'buttons':...               True
#
# [1 rows x 31 columns]
#                                game_name settings.slpVersion  \
# 0  ../../Slippi/Game_20230804T152330.slp              3.15.0
#
#    settings.timerType  settings.inGameMode  settings.friendlyFireEnabled  \
# 0                   2                   32                          True
#
#    settings.isTeams  settings.itemSpawnBehavior  settings.stageId  \
# 0             False                         255                 3
#
#    settings.startingTimerSeconds  settings.enabledItems  ...  \
# 0                            480          1099511627775  ...
#
#                                     metadata.players  metadata.playedOn  \
# 0  {'0': {'names': {'netplay': 'WalkMore', 'code'...            dolphin
#
#    stats.lastFrame  stats.playableFrameCount  \
# 0            17551                     17590
#
#                                         stats.stocks  \
# 0  [{'playerIndex': 0, 'startFrame': -123, 'endFr...
#
#                                    stats.conversions  \
# 0  [{'playerIndex': 0, 'lastHitBy': 1, 'startFram...
#
#                                         stats.combos  \
# 0  [{'playerIndex': 0, 'startFrame': 5, 'endFrame...
#
#                                   stats.actionCounts  \
# 0  [{'playerIndex': 0, 'wavedashCount': 10, 'wave...
#
#                                        stats.overall stats.gameComplete
# 0  [{'playerIndex': 0, 'inputCounts': {'buttons':...               True
#
# [1 rows x 31 columns]
#                                game_name settings.slpVersion  \
# 0  ../../Slippi/Game_20230826T172820.slp              3.15.0
#
#    settings.timerType  settings.inGameMode  settings.friendlyFireEnabled  \
# 0                   2                   32                          True
#
#    settings.isTeams  settings.itemSpawnBehavior  settings.stageId  \
# 0             False                         255                 3
#
#    settings.startingTimerSeconds  settings.enabledItems  ...  \
# 0                            480          1099511627775  ...
#
#                                     metadata.players  metadata.playedOn  \
# 0  {'0': {'names': {'netplay': 'with', 'code': 'W...            dolphin
#
#    stats.lastFrame  stats.playableFrameCount  \
# 0            27673                     27712
#
#                                         stats.stocks  \
# 0  [{'playerIndex': 0, 'startFrame': -123, 'endFr...
#
#                                    stats.conversions  \
# 0  [{'playerIndex': 0, 'lastHitBy': 1, 'startFram...
#
#                                         stats.combos  \
# 0  [{'playerIndex': 0, 'startFrame': 216, 'endFra...
#
#                                   stats.actionCounts  \
# 0  [{'playerIndex': 0, 'wavedashCount': 0, 'wavel...
#
#                                        stats.overall stats.gameComplete
# 0  [{'playerIndex': 0, 'inputCounts': {'buttons':...               True
#
# [1 rows x 31 columns]
#                                game_name settings.slpVersion  \
# 0  ../../Slippi/Game_20231003T202747.slp              3.16.0
#
#    settings.timerType  settings.inGameMode  settings.friendlyFireEnabled  \
# 0                   2                   32                          True
#
#    settings.isTeams  settings.itemSpawnBehavior  settings.stageId  \
# 0             False                         255                28
#
#    settings.startingTimerSeconds  settings.enabledItems  ...  \
# 0                            480          1099511627775  ...
#
#                                     metadata.players  metadata.playedOn  \
# 0  {'0': {'names': {'netplay': 'with', 'code': 'W...            dolphin
#
#    stats.lastFrame  stats.playableFrameCount  \
# 0             6185                      6224
#
#                                         stats.stocks  \
# 0  [{'playerIndex': 0, 'startFrame': -123, 'endFr...
#
#                                    stats.conversions  \
# 0  [{'playerIndex': 0, 'lastHitBy': 1, 'startFram...
#
#                                         stats.combos  \
# 0  [{'playerIndex': 0, 'startFrame': 71, 'endFram...
#
#                                   stats.actionCounts  \
# 0  [{'playerIndex': 0, 'wavedashCount': 0, 'wavel...
#
#                                        stats.overall stats.gameComplete
# 0  [{'playerIndex': 0, 'inputCounts': {'buttons':...               True
#
# [1 rows x 31 columns]
#                                game_name settings.slpVersion  \
# 0  ../../Slippi/Game_20230802T183035.slp              3.15.0
#
#    settings.timerType  settings.inGameMode  settings.friendlyFireEnabled  \
# 0                   2                   32                          True
#
#    settings.isTeams  settings.itemSpawnBehavior  settings.stageId  \
# 0             False                         255                28
#
#    settings.startingTimerSeconds  settings.enabledItems  ...  \
# 0                            480          1099511627775  ...
#
#                                     metadata.players  metadata.playedOn  \
# 0  {'0': {'names': {'netplay': 'Transient Bean', ...            dolphin
#
#    stats.lastFrame  stats.playableFrameCount  \
# 0            14799                     14838
#
#                                         stats.stocks  \
# 0  [{'playerIndex': 0, 'startFrame': -123, 'endFr...
#
#                                    stats.conversions  \
# 0  [{'playerIndex': 0, 'lastHitBy': 1, 'startFram...
#
#                                         stats.combos  \
# 0  [{'playerIndex': 0, 'startFrame': 155, 'endFra...
#
#                                   stats.actionCounts  \
# 0  [{'playerIndex': 0, 'wavedashCount': 10, 'wave...
#
#                                        stats.overall stats.gameComplete
# 0  [{'playerIndex': 0, 'inputCounts': {'buttons':...               True
#
# [1 rows x 31 columns]
#                                game_name settings.slpVersion  \
# 0  ../../Slippi/Game_20230821T160234.slp              3.15.0
#
#    settings.timerType  settings.inGameMode  settings.friendlyFireEnabled  \
# 0                   2                   32                          True
#
#    settings.isTeams  settings.itemSpawnBehavior  settings.stageId  \
# 0             False                         255                31
#
#    settings.startingTimerSeconds  settings.enabledItems  ...  \
# 0                            480          1099511627775  ...
#
#                                     metadata.players  metadata.playedOn  \
# 0  {'0': {'names': {'netplay': 'with', 'code': 'W...            dolphin
#
#    stats.lastFrame  stats.playableFrameCount  \
# 0            11093                     11132
#
#                                         stats.stocks  \
# 0  [{'playerIndex': 0, 'startFrame': -123, 'endFr...
#
#                                    stats.conversions  \
# 0  [{'playerIndex': 0, 'lastHitBy': 1, 'startFram...
#
#                                         stats.combos  \
# 0  [{'playerIndex': 0, 'startFrame': 126, 'endFra...
#
#                                   stats.actionCounts  \
# 0  [{'playerIndex': 0, 'wavedashCount': 0, 'wavel...
#
#                                        stats.overall stats.gameComplete
# 0  [{'playerIndex': 0, 'inputCounts': {'buttons':...               True
#
# [1 rows x 31 columns]
#                                game_name settings.slpVersion  \
# 0  ../../Slippi/Game_20230809T135209.slp              3.15.0
#
#    settings.timerType  settings.inGameMode  settings.friendlyFireEnabled  \
# 0                   2                   32                          True
#
#    settings.isTeams  settings.itemSpawnBehavior  settings.stageId  \
# 0             False                         255                 3
#
#    settings.startingTimerSeconds  settings.enabledItems  ...  \
# 0                            480          1099511627775  ...
#
#                                     metadata.players  metadata.playedOn  \
# 0  {'0': {'names': {'netplay': 'with', 'code': 'W...            dolphin
#
#    stats.lastFrame  stats.playableFrameCount  \
# 0            20805                     20844
#
#                                         stats.stocks  \
# 0  [{'playerIndex': 0, 'startFrame': -123, 'endFr...
#
#                                    stats.conversions  \
# 0  [{'playerIndex': 1, 'lastHitBy': 0, 'startFram...
#
#                                         stats.combos  \
# 0  [{'playerIndex': 1, 'startFrame': 124, 'endFra...
#
#                                   stats.actionCounts  \
# 0  [{'playerIndex': 0, 'wavedashCount': 0, 'wavel...
#
#                                        stats.overall stats.gameComplete
# 0  [{'playerIndex': 0, 'inputCounts': {'buttons':...               True
#
# [1 rows x 31 columns]
#                                game_name settings.slpVersion  \
# 0  ../../Slippi/Game_20230807T233915.slp              3.15.0
#
#    settings.timerType  settings.inGameMode  settings.friendlyFireEnabled  \
# 0                   2                   32                          True
#
#    settings.isTeams  settings.itemSpawnBehavior  settings.stageId  \
# 0             False                         255                28
#
#    settings.startingTimerSeconds  settings.enabledItems  ...  \
# 0                            480          1099511627775  ...
#
#                                     metadata.players  metadata.playedOn  \
# 0  {'0': {'names': {'netplay': 'Jimbles', 'code':...            dolphin
#
#    stats.lastFrame  stats.playableFrameCount  \
# 0            12541                     12580
#
#                                         stats.stocks  \
# 0  [{'playerIndex': 0, 'startFrame': -123, 'endFr...
#
#                                    stats.conversions  \
# 0  [{'playerIndex': 0, 'lastHitBy': 1, 'startFram...
#
#                                         stats.combos  \
# 0  [{'playerIndex': 0, 'startFrame': 130, 'endFra...
#
#                                   stats.actionCounts  \
# 0  [{'playerIndex': 0, 'wavedashCount': 25, 'wave...
#
#                                        stats.overall stats.gameComplete
# 0  [{'playerIndex': 0, 'inputCounts': {'buttons':...               True
#
# [1 rows x 31 columns]
#                                game_name settings.slpVersion  \
# 0  ../../Slippi/Game_20230731T224531.slp              3.15.0
#
#    settings.timerType  settings.inGameMode  settings.friendlyFireEnabled  \
# 0                   2                   32                          True
#
#    settings.isTeams  settings.itemSpawnBehavior  settings.stageId  \
# 0             False                         255                 3
#
#    settings.startingTimerSeconds  settings.enabledItems  ...  \
# 0                            480          1099511627775  ...
#
#                                     metadata.players  metadata.playedOn  \
# 0  {'0': {'names': {'netplay': 'DELTA-20XX', 'cod...            dolphin
#
#    stats.lastFrame  stats.playableFrameCount  \
# 0             3953                      3992
#
#                                         stats.stocks  \
# 0  [{'playerIndex': 0, 'startFrame': -123, 'endFr...
#
#                                    stats.conversions  \
# 0  [{'playerIndex': 0, 'lastHitBy': 1, 'startFram...
#
#                                         stats.combos  \
# 0  [{'playerIndex': 0, 'startFrame': 245, 'endFra...
#
#                                   stats.actionCounts  \
# 0  [{'playerIndex': 0, 'wavedashCount': 0, 'wavel...
#
#                                        stats.overall stats.gameComplete
# 0  [{'playerIndex': 0, 'inputCounts': {'buttons':...               True
#
# [1 rows x 31 columns]
#                                game_name settings.slpVersion  \
# 0  ../../Slippi/Game_20230721T234341.slp              3.15.0
#
#    settings.timerType  settings.inGameMode  settings.friendlyFireEnabled  \
# 0                   2                   32                          True
#
#    settings.isTeams  settings.itemSpawnBehavior  settings.stageId  \
# 0             False                         255                28
#
#    settings.startingTimerSeconds  settings.enabledItems  ...  \
# 0                            480          1099511627775  ...
#
#                                     metadata.players  metadata.playedOn  \
# 0  {'0': {'names': {'netplay': 'with', 'code': 'W...            dolphin
#
#    stats.lastFrame  stats.playableFrameCount  \
# 0            17128                     17167
#
#                                         stats.stocks  \
# 0  [{'playerIndex': 0, 'startFrame': -123, 'endFr...
#
#                                    stats.conversions  \
# 0  [{'playerIndex': 1, 'lastHitBy': 0, 'startFram...
#
#                                         stats.combos  \
# 0  [{'playerIndex': 1, 'startFrame': 294, 'endFra...
#
#                                   stats.actionCounts  \
# 0  [{'playerIndex': 0, 'wavedashCount': 1, 'wavel...
#
#                                        stats.overall stats.gameComplete
# 0  [{'playerIndex': 0, 'inputCounts': {'buttons':...               True
#
# [1 rows x 31 columns]
#                                game_name settings.slpVersion  \
# 0  ../../Slippi/Game_20230724T004013.slp              3.15.0
#
#    settings.timerType  settings.inGameMode  settings.friendlyFireEnabled  \
# 0                   2                   32                          True
#
#    settings.isTeams  settings.itemSpawnBehavior  settings.stageId  \
# 0             False                         255                 8
#
#    settings.startingTimerSeconds  settings.enabledItems  ...  \
# 0                            480          1099511627775  ...
#
#                                     metadata.players  metadata.playedOn  \
# 0  {'0': {'names': {'netplay': 'Marbleman14', 'co...            dolphin
#
#    stats.lastFrame  stats.playableFrameCount  \
# 0            15618                     15657
#
#                                         stats.stocks  \
# 0  [{'playerIndex': 0, 'startFrame': -123, 'endFr...
#
#                                    stats.conversions  \
# 0  [{'playerIndex': 1, 'lastHitBy': 0, 'startFram...
#
#                                         stats.combos  \
# 0  [{'playerIndex': 1, 'startFrame': 88, 'endFram...
#
#                                   stats.actionCounts  \
# 0  [{'playerIndex': 0, 'wavedashCount': 0, 'wavel...
#
#                                        stats.overall stats.gameComplete
# 0  [{'playerIndex': 0, 'inputCounts': {'buttons':...               True
#
# [1 rows x 31 columns]
#                                game_name settings.slpVersion  \
# 0  ../../Slippi/Game_20230806T194740.slp              3.15.0
#
#    settings.timerType  settings.inGameMode  settings.friendlyFireEnabled  \
# 0                   2                   32                          True
#
#    settings.isTeams  settings.itemSpawnBehavior  settings.stageId  \
# 0             False                         255                 3
#
#    settings.startingTimerSeconds  settings.enabledItems  ...  \
# 0                            480          1099511627775  ...
#
#                                     metadata.players  metadata.playedOn  \
# 0  {'0': {'names': {'netplay': 'with', 'code': 'W...            dolphin
#
#    stats.lastFrame  stats.playableFrameCount  \
# 0            20447                     20486
#
#                                         stats.stocks  \
# 0  [{'playerIndex': 0, 'startFrame': -123, 'endFr...
#
#                                    stats.conversions  \
# 0  [{'playerIndex': 0, 'lastHitBy': 1, 'startFram...
#
#                                         stats.combos  \
# 0  [{'playerIndex': 0, 'startFrame': 247, 'endFra...
#
#                                   stats.actionCounts  \
# 0  [{'playerIndex': 0, 'wavedashCount': 3, 'wavel...
#
#                                        stats.overall stats.gameComplete
# 0  [{'playerIndex': 0, 'inputCounts': {'buttons':...               True
#
# [1 rows x 31 columns]
#                                game_name settings.slpVersion  \
# 0  ../../Slippi/Game_20230903T230538.slp              3.15.0
#
#    settings.timerType  settings.inGameMode  settings.friendlyFireEnabled  \
# 0                   2                   32                          True
#
#    settings.isTeams  settings.itemSpawnBehavior  settings.stageId  \
# 0             False                         255                31
#
#    settings.startingTimerSeconds  settings.enabledItems  ...  \
# 0                            480          1099511627775  ...
#
#                                     metadata.players  metadata.playedOn  \
# 0  {'0': {'names': {'netplay': 'with', 'code': 'W...            dolphin
#
#    stats.lastFrame  stats.playableFrameCount  \
# 0            19472                     19511
#
#                                         stats.stocks  \
# 0  [{'playerIndex': 0, 'startFrame': -123, 'endFr...
#
#                                    stats.conversions  \
# 0  [{'playerIndex': 1, 'lastHitBy': 0, 'startFram...
#
#                                         stats.combos  \
# 0  [{'playerIndex': 1, 'startFrame': 11, 'endFram...
#
#                                   stats.actionCounts  \
# 0  [{'playerIndex': 0, 'wavedashCount': 0, 'wavel...
#
#                                        stats.overall stats.gameComplete
# 0  [{'playerIndex': 0, 'inputCounts': {'buttons':...               True
#
# [1 rows x 31 columns]
#                                game_name settings.slpVersion  \
# 0  ../../Slippi/Game_20230825T192844.slp              3.15.0
#
#    settings.timerType  settings.inGameMode  settings.friendlyFireEnabled  \
# 0                   2                   32                          True
#
#    settings.isTeams  settings.itemSpawnBehavior  settings.stageId  \
# 0             False                         255                32
#
#    settings.startingTimerSeconds  settings.enabledItems  ...  \
# 0                            480          1099511627775  ...
#
#                                     metadata.players  metadata.playedOn  \
# 0  {'0': {'names': {'netplay': 'with', 'code': 'W...            dolphin
#
#    stats.lastFrame  stats.playableFrameCount  \
# 0             7817                      7856
#
#                                         stats.stocks  \
# 0  [{'playerIndex': 0, 'startFrame': -123, 'endFr...
#
#                                    stats.conversions  \
# 0  [{'playerIndex': 1, 'lastHitBy': 0, 'startFram...
#
#                                         stats.combos  \
# 0  [{'playerIndex': 1, 'startFrame': 78, 'endFram...
#
#                                   stats.actionCounts  \
# 0  [{'playerIndex': 0, 'wavedashCount': 0, 'wavel...
#
#                                        stats.overall stats.gameComplete
# 0  [{'playerIndex': 0, 'inputCounts': {'buttons':...               True
#
# [1 rows x 31 columns]
#                                game_name settings.slpVersion  \
# 0  ../../Slippi/Game_20230810T224323.slp              3.15.0
#
#    settings.timerType  settings.inGameMode  settings.friendlyFireEnabled  \
# 0                   2                   32                          True
#
#    settings.isTeams  settings.itemSpawnBehavior  settings.stageId  \
# 0             False                         255                31
#
#    settings.startingTimerSeconds  settings.enabledItems  ...  \
# 0                            480          1099511627775  ...
#
#                                     metadata.players  metadata.playedOn  \
# 0  {'0': {'names': {'netplay': 'with', 'code': 'W...            dolphin
#
#    stats.lastFrame  stats.playableFrameCount  \
# 0            12402                     12441
#
#                                         stats.stocks  \
# 0  [{'playerIndex': 0, 'startFrame': -123, 'endFr...
#
#                                    stats.conversions  \
# 0  [{'playerIndex': 1, 'lastHitBy': 0, 'startFram...
#
#                                         stats.combos  \
# 0  [{'playerIndex': 1, 'startFrame': 223, 'endFra...
#
#                                   stats.actionCounts  \
# 0  [{'playerIndex': 0, 'wavedashCount': 0, 'wavel...
#
#                                        stats.overall stats.gameComplete
# 0  [{'playerIndex': 0, 'inputCounts': {'buttons':...               True
#
# [1 rows x 31 columns]
#                                game_name settings.slpVersion  \
# 0  ../../Slippi/Game_20230810T193850.slp              3.15.0
#
#    settings.timerType  settings.inGameMode  settings.friendlyFireEnabled  \
# 0                   2                   32                          True
#
#    settings.isTeams  settings.itemSpawnBehavior  settings.stageId  \
# 0             False                         255                31
#
#    settings.startingTimerSeconds  settings.enabledItems  ...  \
# 0                            480          1099511627775  ...
#
#                                     metadata.players  metadata.playedOn  \
# 0  {'0': {'names': {'netplay': 'with', 'code': 'W...            dolphin
#
#    stats.lastFrame  stats.playableFrameCount  \
# 0            10541                     10580
#
#                                         stats.stocks  \
# 0  [{'playerIndex': 0, 'startFrame': -123, 'endFr...
#
#                                    stats.conversions  \
# 0  [{'playerIndex': 0, 'lastHitBy': 1, 'startFram...
#
#                                         stats.combos  \
# 0  [{'playerIndex': 0, 'startFrame': 0, 'endFrame...
#
#                                   stats.actionCounts  \
# 0  [{'playerIndex': 0, 'wavedashCount': 0, 'wavel...
#
#                                        stats.overall stats.gameComplete
# 0  [{'playerIndex': 0, 'inputCounts': {'buttons':...               True
#
# [1 rows x 31 columns]
#                                game_name settings.slpVersion  \
# 0  ../../Slippi/Game_20231010T180239.slp              3.16.0
#
#    settings.timerType  settings.inGameMode  settings.friendlyFireEnabled  \
# 0                   2                   32                          True
#
#    settings.isTeams  settings.itemSpawnBehavior  settings.stageId  \
# 0             False                         255                 3
#
#    settings.startingTimerSeconds  settings.enabledItems  ...  \
# 0                            480          1099511627775  ...
#
#                                     metadata.players  metadata.playedOn  \
# 0  {'0': {'names': {'netplay': 'with', 'code': 'W...            dolphin
#
#    stats.lastFrame  stats.playableFrameCount  \
# 0            10890                     10929
#
#                                         stats.stocks  \
# 0  [{'playerIndex': 0, 'startFrame': -123, 'endFr...
#
#                                    stats.conversions  \
# 0  [{'playerIndex': 0, 'lastHitBy': 1, 'startFram...
#
#                                         stats.combos  \
# 0  [{'playerIndex': 0, 'startFrame': 29, 'endFram...
#
#                                   stats.actionCounts  \
# 0  [{'playerIndex': 0, 'wavedashCount': 2, 'wavel...
#
#                                        stats.overall stats.gameComplete
# 0  [{'playerIndex': 0, 'inputCounts': {'buttons':...               True
#
# [1 rows x 31 columns]
#                                game_name settings.slpVersion  \
# 0  ../../Slippi/Game_20230805T233645.slp              3.15.0
#
#    settings.timerType  settings.inGameMode  settings.friendlyFireEnabled  \
# 0                   2                   32                          True
#
#    settings.isTeams  settings.itemSpawnBehavior  settings.stageId  \
# 0             False                         255                 2
#
#    settings.startingTimerSeconds  settings.enabledItems  ...  \
# 0                            480          1099511627775  ...
#
#                                     metadata.players  metadata.playedOn  \
# 0  {'0': {'names': {'netplay': 'steven', 'code': ...            dolphin
#
#    stats.lastFrame  stats.playableFrameCount  \
# 0             6389                      6428
#
#                                         stats.stocks  \
# 0  [{'playerIndex': 0, 'startFrame': -123, 'endFr...
#
#                                    stats.conversions  \
# 0  [{'playerIndex': 0, 'lastHitBy': 1, 'startFram...
#
#                                         stats.combos  \
# 0  [{'playerIndex': 0, 'startFrame': 397, 'endFra...
#
#                                   stats.actionCounts  \
# 0  [{'playerIndex': 0, 'wavedashCount': 0, 'wavel...
#
#                                        stats.overall stats.gameComplete
# 0  [{'playerIndex': 0, 'inputCounts': {'buttons':...               True
#
# [1 rows x 31 columns]
#                                game_name settings.slpVersion  \
# 0  ../../Slippi/Game_20230910T123214.slp              3.15.0
#
#    settings.timerType  settings.inGameMode  settings.friendlyFireEnabled  \
# 0                   2                   32                          True
#
#    settings.isTeams  settings.itemSpawnBehavior  settings.stageId  \
# 0             False                         255                 8
#
#    settings.startingTimerSeconds  settings.enabledItems  ...  \
# 0                            480          1099511627775  ...
#
#                                     metadata.players  metadata.playedOn  \
# 0  {'0': {'names': {}, 'characters': {'14': 137}}...            dolphin
#
#    stats.lastFrame  stats.playableFrameCount  \
# 0               13                        52
#
#                                         stats.stocks  stats.conversions  \
# 0  [{'playerIndex': 0, 'startFrame': -123, 'endFr...                 []
#
#    stats.combos                                 stats.actionCounts  \
# 0            []  [{'playerIndex': 0, 'wavedashCount': 0, 'wavel...
#
#                                        stats.overall stats.gameComplete
# 0  [{'playerIndex': 0, 'inputCounts': {'buttons':...               True
#
# [1 rows x 31 columns]
#                                game_name settings.slpVersion  \
# 0  ../../Slippi/Game_20230722T195543.slp              3.15.0
#
#    settings.timerType  settings.inGameMode  settings.friendlyFireEnabled  \
# 0                   2                   32                          True
#
#    settings.isTeams  settings.itemSpawnBehavior  settings.stageId  \
# 0             False                         255                31
#
#    settings.startingTimerSeconds  settings.enabledItems  ...  \
# 0                            480          1099511627775  ...
#
#                                     metadata.players  metadata.playedOn  \
# 0  {'0': {'names': {'netplay': 'Dr. Deeznutz', 'c...            dolphin
#
#    stats.lastFrame  stats.playableFrameCount  \
# 0             7929                      7968
#
#                                         stats.stocks  \
# 0  [{'playerIndex': 0, 'startFrame': -123, 'endFr...
#
#                                    stats.conversions  \
# 0  [{'playerIndex': 0, 'lastHitBy': 1, 'startFram...
#
#                                         stats.combos  \
# 0  [{'playerIndex': 0, 'startFrame': 148, 'endFra...
#
#                                   stats.actionCounts  \
# 0  [{'playerIndex': 0, 'wavedashCount': 4, 'wavel...
#
#                                        stats.overall stats.gameComplete
# 0  [{'playerIndex': 0, 'inputCounts': {'buttons':...               True
#
# [1 rows x 31 columns]
#                                game_name settings.slpVersion  \
# 0  ../../Slippi/Game_20230905T201740.slp              3.15.0
#
#    settings.timerType  settings.inGameMode  settings.friendlyFireEnabled  \
# 0                   2                   32                          True
#
#    settings.isTeams  settings.itemSpawnBehavior  settings.stageId  \
# 0             False                         255                 8
#
#    settings.startingTimerSeconds  settings.enabledItems  ...  \
# 0                            480          1099511627775  ...
#
#                                     metadata.players  metadata.playedOn  \
# 0  {'0': {'names': {'netplay': 'with', 'code': 'W...            dolphin
#
#    stats.lastFrame  stats.playableFrameCount  \
# 0             3898                      3937
#
#                                         stats.stocks  \
# 0  [{'playerIndex': 0, 'startFrame': -123, 'endFr...
#
#                                    stats.conversions  \
# 0  [{'playerIndex': 0, 'lastHitBy': 1, 'startFram...
#
#                                         stats.combos  \
# 0  [{'playerIndex': 0, 'startFrame': 173, 'endFra...
#
#                                   stats.actionCounts  \
# 0  [{'playerIndex': 0, 'wavedashCount': 0, 'wavel...
#
#                                        stats.overall stats.gameComplete
# 0  [{'playerIndex': 0, 'inputCounts': {'buttons':...               True
#
# [1 rows x 31 columns]
#                                game_name settings.slpVersion  \
# 0  ../../Slippi/Game_20230826T092629.slp              3.15.0
#
#    settings.timerType  settings.inGameMode  settings.friendlyFireEnabled  \
# 0                   2                   32                          True
#
#    settings.isTeams  settings.itemSpawnBehavior  settings.stageId  \
# 0             False                         255                 8
#
#    settings.startingTimerSeconds  settings.enabledItems  ...  \
# 0                            480          1099511627775  ...
#
#                                     metadata.players  metadata.playedOn  \
# 0  {'0': {'names': {'netplay': 'G-Tier', 'code': ...            dolphin
#
#    stats.lastFrame  stats.playableFrameCount  \
# 0            10987                     11026
#
#                                         stats.stocks  \
# 0  [{'playerIndex': 0, 'startFrame': -123, 'endFr...
#
#                                    stats.conversions  \
# 0  [{'playerIndex': 1, 'lastHitBy': 0, 'startFram...
#
#                                         stats.combos  \
# 0  [{'playerIndex': 1, 'startFrame': 267, 'endFra...
#
#                                   stats.actionCounts  \
# 0  [{'playerIndex': 0, 'wavedashCount': 53, 'wave...
#
#                                        stats.overall stats.gameComplete
# 0  [{'playerIndex': 0, 'inputCounts': {'buttons':...               True
#
# [1 rows x 31 columns]
#                                game_name settings.slpVersion  \
# 0  ../../Slippi/Game_20230807T160708.slp              3.15.0
#
#    settings.timerType  settings.inGameMode  settings.friendlyFireEnabled  \
# 0                   2                   32                          True
#
#    settings.isTeams  settings.itemSpawnBehavior  settings.stageId  \
# 0             False                         255                 2
#
#    settings.startingTimerSeconds  settings.enabledItems  ...  \
# 0                            480          1099511627775  ...
#
#                                     metadata.players  metadata.playedOn  \
# 0  {'0': {'names': {'netplay': 'Rosenbutt', 'code...            dolphin
#
#    stats.lastFrame  stats.playableFrameCount  \
# 0            11211                     11250
#
#                                         stats.stocks  \
# 0  [{'playerIndex': 0, 'startFrame': -123, 'endFr...
#
#                                    stats.conversions  \
# 0  [{'playerIndex': 1, 'lastHitBy': 0, 'startFram...
#
#                                         stats.combos  \
# 0  [{'playerIndex': 1, 'startFrame': 81, 'endFram...
#
#                                   stats.actionCounts  \
# 0  [{'playerIndex': 0, 'wavedashCount': 18, 'wave...
#
#                                        stats.overall stats.gameComplete
# 0  [{'playerIndex': 0, 'inputCounts': {'buttons':...               True
#
# [1 rows x 31 columns]
#                                game_name settings.slpVersion  \
# 0  ../../Slippi/Game_20230719T153644.slp              3.15.0
#
#    settings.timerType  settings.inGameMode  settings.friendlyFireEnabled  \
# 0                   2                   32                          True
#
#    settings.isTeams  settings.itemSpawnBehavior  settings.stageId  \
# 0             False                         255                 2
#
#    settings.startingTimerSeconds  settings.enabledItems  ...  \
# 0                            480          1099511627775  ...
#
#                                     metadata.players  metadata.playedOn  \
# 0  {'0': {'names': {'netplay': 'with', 'code': 'W...            dolphin
#
#    stats.lastFrame  stats.playableFrameCount  \
# 0             9903                      9942
#
#                                         stats.stocks  \
# 0  [{'playerIndex': 0, 'startFrame': -123, 'endFr...
#
#                                    stats.conversions  \
# 0  [{'playerIndex': 0, 'lastHitBy': 1, 'startFram...
#
#                                         stats.combos  \
# 0  [{'playerIndex': 0, 'startFrame': 89, 'endFram...
#
#                                   stats.actionCounts  \
# 0  [{'playerIndex': 0, 'wavedashCount': 0, 'wavel...
#
#                                        stats.overall stats.gameComplete
# 0  [{'playerIndex': 0, 'inputCounts': {'buttons':...               True
#
# [1 rows x 31 columns]
#                                game_name settings.slpVersion  \
# 0  ../../Slippi/Game_20230822T134435.slp              3.15.0
#
#    settings.timerType  settings.inGameMode  settings.friendlyFireEnabled  \
# 0                   2                   32                          True
#
#    settings.isTeams  settings.itemSpawnBehavior  settings.stageId  \
# 0             False                         255                28
#
#    settings.startingTimerSeconds  settings.enabledItems  ...  \
# 0                            480          1099511627775  ...
#
#                                     metadata.players  metadata.playedOn  \
# 0  {'0': {'names': {'netplay': 'with', 'code': 'W...            dolphin
#
#    stats.lastFrame  stats.playableFrameCount  \
# 0                0                        39
#
#                                         stats.stocks  stats.conversions  \
# 0  [{'playerIndex': 0, 'startFrame': -123, 'endFr...                 []
#
#    stats.combos                                 stats.actionCounts  \
# 0            []  [{'playerIndex': 0, 'wavedashCount': 0, 'wavel...
#
#                                        stats.overall stats.gameComplete
# 0  [{'playerIndex': 0, 'inputCounts': {'buttons':...               True
#
# [1 rows x 31 columns]
#                                game_name settings.slpVersion  \
# 0  ../../Slippi/Game_20230904T181220.slp              3.15.0
#
#    settings.timerType  settings.inGameMode  settings.friendlyFireEnabled  \
# 0                   2                   32                          True
#
#    settings.isTeams  settings.itemSpawnBehavior  settings.stageId  \
# 0             False                         255                 3
#
#    settings.startingTimerSeconds  settings.enabledItems  ...  \
# 0                            480          1099511627775  ...
#
#                                     metadata.players  metadata.playedOn  \
# 0  {'0': {'names': {'netplay': 'Big Sauce', 'code...            dolphin
#
#    stats.lastFrame  stats.playableFrameCount  \
# 0            10052                     10091
#
#                                         stats.stocks  \
# 0  [{'playerIndex': 0, 'startFrame': -123, 'endFr...
#
#                                    stats.conversions  \
# 0  [{'playerIndex': 1, 'lastHitBy': 0, 'startFram...
#
#                                         stats.combos  \
# 0  [{'playerIndex': 1, 'startFrame': 174, 'endFra...
#
#                                   stats.actionCounts  \
# 0  [{'playerIndex': 0, 'wavedashCount': 0, 'wavel...
#
#                                        stats.overall stats.gameComplete
# 0  [{'playerIndex': 0, 'inputCounts': {'buttons':...               True
#
# [1 rows x 31 columns]
#                                game_name settings.slpVersion  \
# 0  ../../Slippi/Game_20230821T214659.slp              3.15.0
#
#    settings.timerType  settings.inGameMode  settings.friendlyFireEnabled  \
# 0                   2                   32                          True
#
#    settings.isTeams  settings.itemSpawnBehavior  settings.stageId  \
# 0             False                         255                 2
#
#    settings.startingTimerSeconds  settings.enabledItems  ...  \
# 0                            480          1099511627775  ...
#
#                                     metadata.players  metadata.playedOn  \
# 0  {'0': {'names': {'netplay': 'with', 'code': 'W...            dolphin
#
#    stats.lastFrame  stats.playableFrameCount  \
# 0            15236                     15275
#
#                                         stats.stocks  \
# 0  [{'playerIndex': 0, 'startFrame': -123, 'endFr...
#
#                                    stats.conversions  \
# 0  [{'playerIndex': 1, 'lastHitBy': 0, 'startFram...
#
#                                         stats.combos  \
# 0  [{'playerIndex': 1, 'startFrame': 229, 'endFra...
#
#                                   stats.actionCounts  \
# 0  [{'playerIndex': 0, 'wavedashCount': 0, 'wavel...
#
#                                        stats.overall stats.gameComplete
# 0  [{'playerIndex': 0, 'inputCounts': {'buttons':...               True
#
# [1 rows x 31 columns]
#                                game_name settings.slpVersion  \
# 0  ../../Slippi/Game_20230802T005855.slp              3.15.0
#
#    settings.timerType  settings.inGameMode  settings.friendlyFireEnabled  \
# 0                   2                   32                          True
#
#    settings.isTeams  settings.itemSpawnBehavior  settings.stageId  \
# 0             False                         255                 3
#
#    settings.startingTimerSeconds  settings.enabledItems  ...  \
# 0                            480          1099511627775  ...
#
#                                     metadata.players  metadata.playedOn  \
# 0  {'0': {'names': {'netplay': 'SpaceCoastRep', '...            dolphin
#
#    stats.lastFrame  stats.playableFrameCount  \
# 0            18456                     18495
#
#                                         stats.stocks  \
# 0  [{'playerIndex': 0, 'startFrame': -123, 'endFr...
#
#                                    stats.conversions  \
# 0  [{'playerIndex': 0, 'lastHitBy': 1, 'startFram...
#
#                                         stats.combos  \
# 0  [{'playerIndex': 0, 'startFrame': 49, 'endFram...
#
#                                   stats.actionCounts  \
# 0  [{'playerIndex': 0, 'wavedashCount': 0, 'wavel...
#
#                                        stats.overall stats.gameComplete
# 0  [{'playerIndex': 0, 'inputCounts': {'buttons':...               True
#
# [1 rows x 31 columns]
# ...
# 0  [{'playerIndex': 0, 'startFrame': 9, 'endFrame...
#
#                                   stats.actionCounts  \
# 0  [{'playerIndex': 0, 'wavedashCount': 4, 'wavel...
#
#                                        stats.overall stats.gameComplete
# 0  [{'playerIndex': 0, 'inputCounts': {'buttons':...               True
#
# [1 rows x 31 columns]
#                                game_name settings.slpVersion  \
# 0  ../../Slippi/Game_20230901T163044.slp              3.15.0
#
#    settings.timerType  settings.inGameMode  settings.friendlyFireEnabled  \
# 0                   2                   32                          True
#
#    settings.isTeams  settings.itemSpawnBehavior  settings.stageId  \
# 0             False                         255                 3
#
#    settings.startingTimerSeconds  settings.enabledItems  ...  \
# 0                            480          1099511627775  ...
#
#                                     metadata.players  metadata.playedOn  \
# 0  {'0': {'names': {'netplay': 'ouioui', 'code': ...            dolphin
#
#    stats.lastFrame  stats.playableFrameCount  \
# 0            19953                     19992
#
#                                         stats.stocks  \
# 0  [{'playerIndex': 0, 'startFrame': -123, 'endFr...
#
#                                    stats.conversions  \
# 0  [{'playerIndex': 0, 'lastHitBy': 1, 'startFram...
#
#                                         stats.combos  \
# 0  [{'playerIndex': 0, 'startFrame': 21, 'endFram...
#
#                                   stats.actionCounts  \
# 0  [{'playerIndex': 0, 'wavedashCount': 35, 'wave...
#
#                                        stats.overall stats.gameComplete
# 0  [{'playerIndex': 0, 'inputCounts': {'buttons':...               True
#
# [1 rows x 31 columns]
#                                game_name settings.slpVersion  \
# 0  ../../Slippi/Game_20230724T032639.slp              3.15.0
#
#    settings.timerType  settings.inGameMode  settings.friendlyFireEnabled  \
# 0                   2                   32                          True
#
#    settings.isTeams  settings.itemSpawnBehavior  settings.stageId  \
# 0             False                         255                 2
#
#    settings.startingTimerSeconds  settings.enabledItems  ...  \
# 0                            480          1099511627775  ...
#
#                                     metadata.players  metadata.playedOn  \
# 0  {'0': {'names': {'netplay': 'with', 'code': 'W...            dolphin
#
#    stats.lastFrame  stats.playableFrameCount  \
# 0            10915                     10954
#
#                                         stats.stocks  \
# 0  [{'playerIndex': 0, 'startFrame': -123, 'endFr...
#
#                                    stats.conversions  \
# 0  [{'playerIndex': 0, 'lastHitBy': 1, 'startFram...
#
#                                         stats.combos  \
# 0  [{'playerIndex': 0, 'startFrame': 299, 'endFra...
#
#                                   stats.actionCounts  \
# 0  [{'playerIndex': 0, 'wavedashCount': 0, 'wavel...
#
#                                        stats.overall stats.gameComplete
# 0  [{'playerIndex': 0, 'inputCounts': {'buttons':...               True
#
# [1 rows x 31 columns]
#                                game_name settings.slpVersion  \
# 0  ../../Slippi/Game_20230724T213253.slp              3.15.0
#
#    settings.timerType  settings.inGameMode  settings.friendlyFireEnabled  \
# 0                   2                   32                          True
#
#    settings.isTeams  settings.itemSpawnBehavior  settings.stageId  \
# 0             False                         255                28
#
#    settings.startingTimerSeconds  settings.enabledItems  ...  \
# 0                            480          1099511627775  ...
#
#                                     metadata.players  metadata.playedOn  \
# 0  {'0': {'names': {'netplay': 'Jesus', 'code': '...            dolphin
#
#    stats.lastFrame  stats.playableFrameCount  \
# 0             1923                      1962
#
#                                         stats.stocks  \
# 0  [{'playerIndex': 0, 'startFrame': -123, 'endFr...
#
#                                    stats.conversions  \
# 0  [{'playerIndex': 1, 'lastHitBy': 0, 'startFram...
#
#                                         stats.combos  \
# 0  [{'playerIndex': 1, 'startFrame': 71, 'endFram...
#
#                                   stats.actionCounts  \
# 0  [{'playerIndex': 0, 'wavedashCount': 0, 'wavel...
#
#                                        stats.overall stats.gameComplete
# 0  [{'playerIndex': 0, 'inputCounts': {'buttons':...               True
#
# [1 rows x 31 columns]
#                                game_name settings.slpVersion  \
# 0  ../../Slippi/Game_20230914T234739.slp              3.15.0
#
#    settings.timerType  settings.inGameMode  settings.friendlyFireEnabled  \
# 0                   2                   32                          True
#
#    settings.isTeams  settings.itemSpawnBehavior  settings.stageId  \
# 0             False                         255                 3
#
#    settings.startingTimerSeconds  settings.enabledItems  ...  \
# 0                            480          1099511627775  ...
#
#                                     metadata.players  metadata.playedOn  \
# 0  {'0': {'names': {'netplay': 'MaractusSSB', 'co...            dolphin
#
#    stats.lastFrame  stats.playableFrameCount  \
# 0            11063                     11102
#
#                                         stats.stocks  \
# 0  [{'playerIndex': 0, 'startFrame': -123, 'endFr...
#
#                                    stats.conversions  \
# 0  [{'playerIndex': 1, 'lastHitBy': 0, 'startFram...
#
#                                         stats.combos  \
# 0  [{'playerIndex': 1, 'startFrame': 533, 'endFra...
#
#                                   stats.actionCounts  \
# 0  [{'playerIndex': 0, 'wavedashCount': 48, 'wave...
#
#                                        stats.overall stats.gameComplete
# 0  [{'playerIndex': 0, 'inputCounts': {'buttons':...               True
#
# [1 rows x 31 columns]
#                                game_name settings.slpVersion  \
# 0  ../../Slippi/Game_20230810T150056.slp              3.15.0
#
#    settings.timerType  settings.inGameMode  settings.friendlyFireEnabled  \
# 0                   2                   32                          True
#
#    settings.isTeams  settings.itemSpawnBehavior  settings.stageId  \
# 0             False                         255                 3
#
#    settings.startingTimerSeconds  settings.enabledItems  ...  \
# 0                            480          1099511627775  ...
#
#                                     metadata.players  metadata.playedOn  \
# 0  {'0': {'names': {'netplay': 'Bad Judgement', '...            dolphin
#
#    stats.lastFrame  stats.playableFrameCount  \
# 0            28800                     28839
#
#                                         stats.stocks  \
# 0  [{'playerIndex': 0, 'startFrame': -123, 'endFr...
#
#                                    stats.conversions  \
# 0  [{'playerIndex': 1, 'lastHitBy': 0, 'startFram...
#
#                                         stats.combos  \
# 0  [{'playerIndex': 1, 'startFrame': 131, 'endFra...
#
#                                   stats.actionCounts  \
# 0  [{'playerIndex': 0, 'wavedashCount': 7, 'wavel...
#
#                                        stats.overall stats.gameComplete
# 0  [{'playerIndex': 0, 'inputCounts': {'buttons':...               True
#
# [1 rows x 31 columns]
#                                game_name settings.slpVersion  \
# 0  ../../Slippi/Game_20230812T003105.slp              3.15.0
#
#    settings.timerType  settings.inGameMode  settings.friendlyFireEnabled  \
# 0                   2                   32                          True
#
#    settings.isTeams  settings.itemSpawnBehavior  settings.stageId  \
# 0             False                         255                 3
#
#    settings.startingTimerSeconds  settings.enabledItems  ...  \
# 0                            480          1099511627775  ...
#
#                                     metadata.players  metadata.playedOn  \
# 0  {'0': {'names': {'netplay': 'with', 'code': 'W...            dolphin
#
#    stats.lastFrame  stats.playableFrameCount  \
# 0              369                       408
#
#                                         stats.stocks  \
# 0  [{'playerIndex': 0, 'startFrame': -123, 'endFr...
#
#                                    stats.conversions  \
# 0  [{'playerIndex': 0, 'lastHitBy': 1, 'startFram...
#
#                                         stats.combos  \
# 0  [{'playerIndex': 0, 'startFrame': 154, 'endFra...
#
#                                   stats.actionCounts  \
# 0  [{'playerIndex': 0, 'wavedashCount': 0, 'wavel...
#
#                                        stats.overall stats.gameComplete
# 0  [{'playerIndex': 0, 'inputCounts': {'buttons':...               True
#
# [1 rows x 31 columns]
#                                game_name settings.slpVersion  \
# 0  ../../Slippi/Game_20230806T000805.slp              3.15.0
#
#    settings.timerType  settings.inGameMode  settings.friendlyFireEnabled  \
# 0                   2                   32                          True
#
#    settings.isTeams  settings.itemSpawnBehavior  settings.stageId  \
# 0             False                         255                 3
#
#    settings.startingTimerSeconds  settings.enabledItems  ...  \
# 0                            480          1099511627775  ...
#
#                                     metadata.players  metadata.playedOn  \
# 0  {'0': {'names': {'netplay': 'Latty128', 'code'...            dolphin
#
#    stats.lastFrame  stats.playableFrameCount  \
# 0            12697                     12736
#
#                                         stats.stocks  \
# 0  [{'playerIndex': 0, 'startFrame': -123, 'endFr...
#
#                                    stats.conversions  \
# 0  [{'playerIndex': 1, 'lastHitBy': 0, 'startFram...
#
#                                         stats.combos  \
# 0  [{'playerIndex': 1, 'startFrame': 169, 'endFra...
#
#                                   stats.actionCounts  \
# 0  [{'playerIndex': 0, 'wavedashCount': 26, 'wave...
#
#                                        stats.overall stats.gameComplete
# 0  [{'playerIndex': 0, 'inputCounts': {'buttons':...               True
#
# [1 rows x 31 columns]
#                                game_name settings.slpVersion  \
# 0  ../../Slippi/Game_20230901T123820.slp              3.15.0
#
#    settings.timerType  settings.inGameMode  settings.friendlyFireEnabled  \
# 0                   2                   32                          True
#
#    settings.isTeams  settings.itemSpawnBehavior  settings.stageId  \
# 0             False                         255                 3
#
#    settings.startingTimerSeconds  settings.enabledItems  ...  \
# 0                            480          1099511627775  ...
#
#                                     metadata.players  metadata.playedOn  \
# 0  {'0': {'names': {'netplay': 'BurntToast', 'cod...            dolphin
#
#    stats.lastFrame  stats.playableFrameCount  \
# 0            14768                     14807
#
#                                         stats.stocks  \
# 0  [{'playerIndex': 0, 'startFrame': -123, 'endFr...
#
#                                    stats.conversions  \
# 0  [{'playerIndex': 0, 'lastHitBy': 1, 'startFram...
#
#                                         stats.combos  \
# 0  [{'playerIndex': 0, 'startFrame': 99, 'endFram...
#
#                                   stats.actionCounts  \
# 0  [{'playerIndex': 0, 'wavedashCount': 2, 'wavel...
#
#                                        stats.overall stats.gameComplete
# 0  [{'playerIndex': 0, 'inputCounts': {'buttons':...               True
#
# [1 rows x 31 columns]
#                                game_name settings.slpVersion  \
# 0  ../../Slippi/Game_20230824T140725.slp              3.15.0
#
#    settings.timerType  settings.inGameMode  settings.friendlyFireEnabled  \
# 0                   2                   32                          True
#
#    settings.isTeams  settings.itemSpawnBehavior  settings.stageId  \
# 0             False                         255                28
#
#    settings.startingTimerSeconds  settings.enabledItems  ...  \
# 0                            480          1099511627775  ...
#
#                                     metadata.players  metadata.playedOn  \
# 0  {'0': {'names': {'netplay': 'with', 'code': 'W...            dolphin
#
#    stats.lastFrame  stats.playableFrameCount  \
# 0            12177                     12216
#
#                                         stats.stocks  \
# 0  [{'playerIndex': 0, 'startFrame': -123, 'endFr...
#
#                                    stats.conversions  \
# 0  [{'playerIndex': 1, 'lastHitBy': 0, 'startFram...
#
#                                         stats.combos  \
# 0  [{'playerIndex': 1, 'startFrame': 172, 'endFra...
#
#                                   stats.actionCounts  \
# 0  [{'playerIndex': 0, 'wavedashCount': 0, 'wavel...
#
#                                        stats.overall stats.gameComplete
# 0  [{'playerIndex': 0, 'inputCounts': {'buttons':...               True
#
# [1 rows x 31 columns]
#                                game_name settings.slpVersion  \
# 0  ../../Slippi/Game_20230805T185615.slp              3.15.0
#
#    settings.timerType  settings.inGameMode  settings.friendlyFireEnabled  \
# 0                   2                   32                          True
#
#    settings.isTeams  settings.itemSpawnBehavior  settings.stageId  \
# 0             False                         255                32
#
#    settings.startingTimerSeconds  settings.enabledItems  ...  \
# 0                            480          1099511627775  ...
#
#                                     metadata.players  metadata.playedOn  \
# 0  {'0': {'names': {'netplay': 'controllerdrift',...            dolphin
#
#    stats.lastFrame  stats.playableFrameCount  \
# 0            13995                     14034
#
#                                         stats.stocks  \
# 0  [{'playerIndex': 0, 'startFrame': -123, 'endFr...
#
#                                    stats.conversions  \
# 0  [{'playerIndex': 0, 'lastHitBy': 1, 'startFram...
#
#                                         stats.combos  \
# 0  [{'playerIndex': 0, 'startFrame': 94, 'endFram...
#
#                                   stats.actionCounts  \
# 0  [{'playerIndex': 0, 'wavedashCount': 77, 'wave...
#
#                                        stats.overall stats.gameComplete
# 0  [{'playerIndex': 0, 'inputCounts': {'buttons':...               True
#
# [1 rows x 31 columns]
#                                game_name settings.slpVersion  \
# 0  ../../Slippi/Game_20230910T005025.slp              3.15.0
#
#    settings.timerType  settings.inGameMode  settings.friendlyFireEnabled  \
# 0                   2                   32                          True
#
#    settings.isTeams  settings.itemSpawnBehavior  settings.stageId  \
# 0             False                         255                 3
#
#    settings.startingTimerSeconds  settings.enabledItems  ...  \
# 0                            480          1099511627775  ...
#
#                                     metadata.players  metadata.playedOn  \
# 0  {'0': {'names': {'netplay': 'with', 'code': 'W...            dolphin
#
#    stats.lastFrame  stats.playableFrameCount  \
# 0            13009                     13048
#
#                                         stats.stocks  \
# 0  [{'playerIndex': 0, 'startFrame': -123, 'endFr...
#
#                                    stats.conversions  \
# 0  [{'playerIndex': 1, 'lastHitBy': 0, 'startFram...
#
#                                         stats.combos  \
# 0  [{'playerIndex': 1, 'startFrame': 135, 'endFra...
#
#                                   stats.actionCounts  \
# 0  [{'playerIndex': 0, 'wavedashCount': 0, 'wavel...
#
#                                        stats.overall stats.gameComplete
# 0  [{'playerIndex': 0, 'inputCounts': {'buttons':...               True
#
# [1 rows x 31 columns]

# %%
output.iloc[0]
# Out:
# game_length                                                             32.9
# stage                                                        Pokémon Stadium
# player_one_display_name                                                 with
# player_two_display_name                                                 meow
# player_one_connect_code                                               WITH#0
# player_two_connect_code                                             MEOW#339
# player_one_user_id                              aPmT3TcxYLaUAlxSDKDsfKFmXC72
# player_two_user_id                              aPmT3TcxYLaUAlxSDKDsfKFmXC72
# player_one_character                                                   Yoshi
# player_two_character                                                   Yoshi
# played_at                                               2023-08-17T23:48:00Z
# overall                    [{'playerIndex': 0, 'inputCounts': {'buttons':...
# action_counts              [{'playerIndex': 0, 'wavedashCount': 0, 'wavel...
# game_complete                                                           True
# Name: 0, dtype: object
