# %% [markdown]
# # Setup

# %%
# import os
# from os import listdir
# from os.path import isfile, join
# import re
# import numpy as np
import pandas as pd
# import json
# import matplotlib.pyplot as plt
import blempamhmuuuuummm as bph


# for one game. Used for testing
# test_game_path = "test_game.slp"
# bph.write_game_json(test_game_path)
# game = bph.load_single_game('game_analytics/test_game.json', pd.DataFrame())


# write game json files
slippi_archive_path = "../../Slippi"
bph.write_games_json(slippi_archive_path)

# read game json into memory
all_games = bph.load_multiple_games("game_analytics")
my_id = bph.find_my_id(all_games) # this guesses your id based on the most popular id in your archive. 
# my_id = "aPmT3TcxYLaUAlxSDKDsfKFmXC72" # or you can set it manually
# Out:
# No metadata for:  game_analytics/Game_20231002T112717.json
# No metadata for:  game_analytics/Game_20230821T074359.json
# No metadata for:  game_analytics/Game_20231003T144755.json
# No metadata for:  game_analytics/Game_20230810T141105.json
# No metadata for:  game_analytics/Game_20231001T235749.json
# No metadata for:  game_analytics/Game_20231018T195855.json
# No metadata for:  game_analytics/Game_20230827T101530.json
# No metadata for:  game_analytics/Game_20230807T091818.json
# No metadata for:  game_analytics/Game_20230806T200651.json
# No metadata for:  game_analytics/Game_20230814T213419.json
# No metadata for:  game_analytics/Game_20230722T085734.json
# No metadata for:  game_analytics/Game_20231021T081930.json
# No metadata for:  game_analytics/Game_20230906T150537.json
# No metadata for:  game_analytics/Game_20230721T154233.json
# No metadata for:  game_analytics/Game_20230919T003340.json
# No metadata for:  game_analytics/Game_20230804T181006.json
# ...

# %% [markdown]
# # Sample Queries

# %%
#scoping
completed_games = bph.finished_games(all_games)
recent_games = bph.recent_games(completed_games, 50) # recent n number of games

# %%
completed_games
# Out:
#       game_length               stage player_one_display_name  \
# 1      217.083333       Yoshi's Story                    with
# 2      102.533333     Pokémon Stadium              Matcha Man
# 4       65.166667  Fountain of Dreams                    ITSU
# 6       18.016667  Fountain of Dreams                    with
# 7      293.166667     Pokémon Stadium                WalkMore
# ...           ...                 ...                     ...
# 6055   228.950000       Yoshi's Story                    with
# 6056    36.716667     Pokémon Stadium                    with
# 6057   157.400000  Fountain of Dreams                     KEV
# 6058   239.016667      Dream Land N64                    with
# 6059   233.566667   Final Destination                 The_OG_
#
#      player_two_display_name player_one_connect_code player_two_connect_code  \
# 1                    VHSTAPE                  WITH#0                 VHS#396
# ...

# %%
# win rates
bph.overall_win_rates(completed_games, my_id)
# Out:
# (2399, 2741, 0.46673151750972763)

# %%
bph.win_rates_for_all_stages(completed_games, my_id)
# Out:
# {'Dream Land N64': 0.5213675213675214,
#  'Final Destination': 0.4827586206896552,
#  "Yoshi's Story": 0.4734982332155477,
#  'Pokémon Stadium': 0.4641638225255973,
#  'Fountain of Dreams': 0.451348182883939,
#  'Battlefield': 0.4310747663551402,
#  "Princess Peach's Castle": 0,
#  'Kongo Jungle': 0,
#  'Brinstar': 0,
#  'Corneria': 0,
#  'Onett': 0,
#  'Mute City': 0,
#  'Rainbow Cruise': 0,
#  'Jungle Japes': 0,
#  'Great Bay': 0,
#  'Hyrule Temple': 0,
#  'Brinstar Depths': 0,
#  "Yoshi's Island": 0,
#  'Green Greens': 0,
#  'Fourside': 0,
#  'Mushroom Kingdom I': 0,
#  'Mushroom Kingdom IIVenom': 0,
#  'Poké Floats': 0,
#  'Big Blue': 0,
#  'Icicle Mountain': 0,
#  'Icetop': 0,
#  'Flat Zone': 0,
#  "Yoshi's Island N64": 0,
#  'Kongo Jungle N64': 0}

# %%
bph.encounter_rates_across_characters(all_games, my_id)
# Out:
# {'Falco': 0.2056420233463035,
#  'Fox': 0.15369649805447472,
#  'Captain Falcon': 0.1208171206225681,
#  'Marth': 0.12062256809338522,
#  'Sheik': 0.06750972762645914,
#  'Jigglypuff': 0.03832684824902724,
#  'Dr. Mario': 0.03151750972762646,
#  'Yoshi': 0.030155642023346304,
#  'Luigi': 0.02821011673151751,
#  'Ganondorf': 0.027431906614785992,
#  'Peach': 0.022957198443579768,
#  'Samus': 0.020622568093385214,
#  'Mario': 0.017120622568093387,
#  'Ice Climbers': 0.015953307392996108,
#  'Pikachu': 0.01536964980544747,
#  'Donkey Kong': 0.014785992217898832,
#  'Roy': 0.014007782101167316,
#  'Young Link': 0.011673151750972763,
#  'Link': 0.011284046692607004,
#  'Mewtwo': 0.0071984435797665365,
#  'Mr. Game & Watch': 0.007003891050583658,
#  'Bowser': 0.004280155642023347,
#  'Ness': 0.004085603112840467,
#  'Kirby': 0.003501945525291829,
#  'Pichu': 0.002723735408560311,
#  'Zelda': 0.002529182879377432}

# %%
bph.l_cancel_rate(recent, my_id)
# Out:
# 0.0

# %%
bph.get_character_win_rates(completed_games, my_id)
# Out:
# {'Sheik': 0.3032069970845481,
#  'Pikachu': 0.379746835443038,
#  'Zelda': 0.38461538461538464,
#  'Captain Falcon': 0.3883495145631068,
#  'Peach': 0.4152542372881356,
#  'Samus': 0.42452830188679247,
#  'Ganondorf': 0.4420289855072464,
#  'Mr. Game & Watch': 0.4444444444444444,
#  'Yoshi': 0.45806451612903226,
#  'Fox': 0.4648786717752235,
#  'Falco': 0.4661582459485224,
#  'Marth': 0.4773462783171521,
#  'Link': 0.4827586206896552,
#  'Dr. Mario': 0.4876543209876543,
#  'Luigi': 0.4896551724137931,
#  'Donkey Kong': 0.6052631578947368,
#  'Ice Climbers': 0.6075949367088608,
#  'Ness': 0.6190476190476191,
#  'Bowser': 0.6363636363636364,
#  'Roy': 0.6388888888888888,
#  'Jigglypuff': 0.649746192893401,
#  'Mario': 0.6704545454545454,
#  'Young Link': 0.6833333333333333,
#  'Kirby': 0.7777777777777778,
#  'Pichu': 0.7857142857142857,
#  'Mewtwo': 0.8378378378378378}

# %%
bph.all_character_tech_options(completed_games, my_id)
# Out:
# {'Captain Falcon': tech_away       0.061726
#  tech_in         0.053247
#  tech_fail       0.654061
#  tech_neutral    0.230965
#  dtype: float64,
#  'Donkey Kong': tech_away       0.050292
#  tech_in         0.078363
#  tech_fail       0.651462
#  tech_neutral    0.219883
#  dtype: float64,
#  'Fox': tech_away       0.043385
#  tech_in         0.047022
#  tech_fail       0.708165
#  tech_neutral    0.201428
#  dtype: float64,
#  'Mr. Game & Watch': tech_away       0.028571
#  tech_in         0.020408
#  tech_fail       0.763265
#  tech_neutral    0.187755
#  dtype: float64,
#  'Kirby': tech_away       0.0375
#  tech_in         0.0875
#  tech_fail       0.7125
#  tech_neutral    0.1625
#  dtype: float64,
#  'Bowser': tech_away       0.019231
#  tech_in         0.070513
#  tech_fail       0.685897
#  tech_neutral    0.224359
#  dtype: float64,
#  'Link': tech_away       0.036244
#  tech_in         0.054366
#  tech_fail       0.742998
#  tech_neutral    0.166392
#  dtype: float64,
# ...

# %%
bph.get_opponent_history(all_games, "rat")
# Out:
#       game_length            stage player_one_display_name  \
# 6031   311.616667  Pokémon Stadium                    with
#
#      player_two_display_name player_one_connect_code player_two_connect_code  \
# 6031                     rat                  WITH#0                ARIA#911
#
#                 player_one_user_id            player_two_user_id  \
# 6031  aPmT3TcxYLaUAlxSDKDsfKFmXC72  sg5khcm3kcTqs3Z6vySVfnDdRUL2
#
#      player_one_character player_two_character  ...  player_one_tech_fail  \
# 6031                Yoshi              Pikachu  ...                     8
#
#       player_two_tech_away player_two_tech_in player_two_tech_neutral  \
# 6031                     1                  0                       5
#
#      player_two_tech_fail winner_connect_code winning_character  \
# 6031                   13            ARIA#911           Pikachu
#
#                           loser_id  loser_connect_code  losing_character
# ...

# %%
bph.tech_options(recent, my_id)
# Out:
# (286,
#  tech_away        14
#  tech_in          19
#  tech_fail       244
#  tech_neutral      9
#  dtype: int64,
#  tech_away       0.048951
#  tech_in         0.066434
#  tech_fail       0.853147
#  tech_neutral    0.031469
#  dtype: float64)

# %%
bph.avg_shmove_counts(completed_games, my_id, False)
# Out:
# wavedash_count     16.692996
# waveland_count      4.058755
# airdodge_count      3.131907
# dashdance_count    23.658755
# spotdodge_count     1.342412
# roll_count          5.626459
# ledgegrab_count     4.613813
# dtype: float64

# %%
bph.avg_shmove_counts(completed_games, my_id)
# Out:
# wavedash_count      0.222374
# waveland_count      0.236965
# airdodge_count      1.566537
# dashdance_count     1.573152
# spotdodge_count     0.439300
# roll_count         26.909144
# ledgegrab_count     4.141051
# dtype: float64

# %%
connect_code_arr = bph.find_opponents_connect_codes(all_games, my_id)
# print(bph.find_opponents_info(all_games, my_id))
# find_connect_code(all_games, opponent):    # can use id or display name

# %%
# Don't run this too much about 35 minutes for 3144 connect_codes    
# bph.save_opponent_info(connect_code_arr)

# limitation: saves unranked people as silver 1 with 0W/0L and a rank of 1100
# bph.find_opponent_info(connect_code)

# %%
my_connect_code = "WITH#0"
ranked_player_games = bph.games_with_ranked_opponents(completed_games, my_connect_code)

# %%
bph.win_rate_for_stage(ranked_player_games)

# %%
# bph.stage_cat_viz(ranked_player_games)
# bph.opp_char_cat_viz(ranked_player_games)
import seaborn as sns
to_viz = ranked_player_games[['win', 'connect_code', 'winner_connect_code', 'rating', 'stage', 'opponent_char']].drop_duplicates().reset_index(drop=True)
sns.boxplot(data=to_viz, x="rating", y="stage", hue="win")
# Out:
# <Axes: xlabel='rating', ylabel='stage'>

# %%
bph.opp_char_box_viz(ranked_player_games)

# %%
ranked_player_games.sort_values('rating', ascending=False).head(40)
# Out:
#                            date connect_code          rank   rating   wins  \
# 720  2023-10-30 11:43:59.977054     FUNK#650  Rank 40 [NA]  2502.09  178.0
# 721  2023-10-30 11:43:59.977054     FUNK#650  Rank 40 [NA]  2502.09  178.0
# 619  2023-10-30 11:40:41.522358     DEEZ#420   Grandmaster  2436.98   35.0
# 43   2023-10-30 11:13:44.056435      UPG#199     Diamond 1  2020.02  976.0
# 42   2023-10-30 11:13:44.056435      UPG#199     Diamond 1  2020.02  976.0
# 153  2023-10-30 11:13:44.056435      UPG#199     Diamond 1  2020.02  976.0
# 597  2023-10-30 11:40:11.927617      OLI#719    Platinum 2  1912.81  109.0
# 598  2023-10-30 11:40:11.927617      OLI#719    Platinum 2  1912.81  109.0
# 614  2023-10-30 11:40:35.533726      GOOPY#1    Platinum 2  1904.80  117.0
# 499  2023-10-30 11:20:50.363745     RYUK#599    Platinum 1  1773.78   58.0
# 421  2023-10-30 11:36:03.002638     LMNL#481    Platinum 1  1755.48  109.0
# ...

# %%
bph.stage_box_viz(ranked_player_games)

# %%
from sklearn import linear_model
reg = linear_model.LinearRegression()
reg.fit([[0, 0], [1, 1], [2, 2]], [0, 1, 2])
reg.coef_
# Out:
# array([0.5, 0.5])

# %%
# Out:
# hello
